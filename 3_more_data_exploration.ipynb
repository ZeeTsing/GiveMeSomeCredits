# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
from collections import Counter

# %%
train_path = 'G:/Github/GiveMeSomeCredits/data/cs-training.csv'
test_path = 'G:/Github/GiveMeSomeCredits/data/cs-test.csv'
df_train = pd.read_csv(train_path,index_col = 0).reset_index()
df_test = pd.read_csv(test_path,index_col = 0).reset_index()
df_train = df_train.fillna(0)
df_test = df_test.fillna(0)

# %%
sns.heatmap(df_train.drop(columns=['index']).corr(),linewidths=.5,cmap="Blues")

# %%
df_train.drop(columns=['index']).corr()
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                              1.000000
# RevolvingUtilizationOfUnsecuredLines         -0.001802
# age                                          -0.115386
# NumberOfTime30-59DaysPastDueNotWorse          0.125587
# DebtRatio                                    -0.007602
# MonthlyIncome                                -0.013322
# NumberOfOpenCreditLinesAndLoans              -0.029669
# NumberOfTimes90DaysLate                       0.117175
# NumberRealEstateLoansOrLines                 -0.007038
# NumberOfTime60-89DaysPastDueNotWorse          0.102261
# NumberOfDependents                            0.046869
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                 -0.001802
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005898
# ...

# %% [markdown]
# Turns out there are 3 variables very closely correlated
#
# Maybe we should consider removing 2 of them when training the model
